# %%
print('hello world')
# Out:
# hello world

# %%
b = ('hello coders')

# %%
print(b)
# Out:
# hello coders

# %%
45+56
# Out:
# 101

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ![pexels-timothy-paule-ii-2002719.jpg](data:image/jpeg;base64,...)

# %%
#this is a command to assign a value
b=4
c=1
d=b+c
print(d)
# Out:
# 5

# %%
#k = KEYWORDS
#def
#None
#True
#False

# %%
#I = Identifiers

# %%
a = 4
b = 4.5
c = 'coders'
d = 3+5j
e = 5**3
f = 9/2
g = 9//2
h = None

# %%
d.real
# Out:
# 3.0

# %%
d.imag
# Out:
# 5.0

# %%
True + False
# Out:
# 1

# %%
f
# Out:
# 4.5

# %%
g
# Out:
# 4

# %%
a+b
# Out:
# 8.5

# %%
a=4

# %%
if a<6 or a>9:
  print('Anuj')
# Out:
# Anuj

# %%
a=4
b=8

# %%
if a<6 and a>9:
 print('Anuj')

# %%
food = 'pasta'

if food is None:
  print('just in some time,let the class finish')
else:
  print('here,is',food)
# Out:
# here,is pasta

# %%
age=15
if age>18:
  print('you are young')
elif 21<age<23:
  print('you may be young')
else:
  print('choti bacchi ho kya')
# Out:
# choti bacchi ho kya
